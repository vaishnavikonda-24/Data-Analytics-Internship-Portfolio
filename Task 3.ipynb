# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07568456-291d-44d8-a975-935cceef2842" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07568456-291d-44d8-a975-935cceef2842">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
for file in os.listdir():
    print(file)
# Out:
# .config
# cleaned_fruit_dataset (2).csv
# cleaned_fruit_dataset.csv
# cleaned_fruit_dataset (1).csv
# cleaned_fruit_dataset (3).csv
# sample_data

# %%
# !find /kaggle/input -name "*.csv"

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import pandas as pd

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit_dataset.csv', 'sample_data']
# Out:
# ['fruit_dataset.csv', 'sample_data']

# %%
['cleaned_fruit_dataset.csv']
# Out:
# ['cleaned_fruit_dataset.csv']

# %%
['fruit_dataset.csv']
# Out:
# ['fruit_dataset.csv']

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit.csv']
# Out:
# ['fruit.csv']

# %%
['cleaned_fruit_dataset.csv']
# Out:
# ['cleaned_fruit_dataset.csv']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['myfruitdata.csv', 'sample_data']
# Out:
# ['myfruitdata.csv', 'sample_data']

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles Available:")
print(os.listdir())
# Out:
# Current Folder:
# /content
#
# Files Available:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit.csv']
# Out:
# ['fruit.csv']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles Available:")
print(os.listdir())
# Out:
# Current Folder:
# /content
#
# Files Available:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles:")
for f in os.listdir():
    print(f)
# Out:
# Current Directory:
# /content
#
# Files:
# .config
# cleaned_fruit_dataset (2).csv
# cleaned_fruit_dataset.csv
# cleaned_fruit_dataset (1).csv
# cleaned_fruit_dataset (3).csv
# sample_data

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles Available:")
print(os.listdir())
# Out:
# Current Directory:
# /content
#
# Files Available:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
# !find /kaggle/input -type f | head -20

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit_dataset.csv', 'notebook.ipynb']
# Out:
# ['fruit_dataset.csv', 'notebook.ipynb']

# %%
import os

print("Files in current folder:")
print(os.listdir())
# Out:
# Files in current folder:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit_dataset.csv']
# Out:
# ['fruit_dataset.csv']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
['fruit_dataset.csv']
# Out:
# ['fruit_dataset.csv']

# %%
['cleaned_fruit_data.csv']
# Out:
# ['cleaned_fruit_data.csv']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-caccf229-8eb1-4c62-be4d-84c8884091ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-caccf229-8eb1-4c62-be4d-84c8884091ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import pandas as pd
import os

print(os.listdir())   # Find the CSV file name
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles Available:")
print(os.listdir())
# Out:
# Current Directory:
# /content
#
# Files Available:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
import os

print("Current Directory:", os.getcwd())
print("Files:", os.listdir())
# Out:
# Current Directory: /content
# Files: ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-97ce5d1e-1ade-47dc-8cb9-4a8a9c053729" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97ce5d1e-1ade-47dc-8cb9-4a8a9c053729">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'cleaned_fruit_dataset (5).csv', 'sample_data']

# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles Available:")
print(os.listdir())
# Out:
# Current Directory:
# /content
#
# Files Available:
# ['.config', 'cleaned_fruit_dataset (2).csv', 'cleaned_fruit_dataset.csv', 'cleaned_fruit_dataset (1).csv', 'cleaned_fruit_dataset (4).csv', 'cleaned_fruit_dataset (3).csv', 'cleaned_fruit_dataset (5).csv', 'sample_data']

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'sample_data']

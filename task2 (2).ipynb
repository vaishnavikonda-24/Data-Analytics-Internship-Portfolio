# %%
import pandas as pd

df = pd.read_csv("cleaned_fruit_dataset.csv")

df.head()
# Out:
#    Weight  Colour   Label Fruit_Size  Label_Code
# 0     303       3  Banana      Light           0
# 1     370       1   Apple      Heavy           1
# 2     298       3  Banana      Light           0
# 3     277       3  Banana      Light           0
# 4     377       4   Apple      Heavy           1

# %%
df.shape
# Out:
# (17, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Weight      17 non-null     int64
#  1   Colour      17 non-null     int64
#  2   Label       17 non-null     object
#  3   Fruit_Size  17 non-null     object
#  4   Label_Code  17 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 812.0+ bytes

# %%
df.describe()
# Out:
#            Weight     Colour  Label_Code
# count   17.000000  17.000000   17.000000
# mean   334.058824   2.764706    0.470588
# std     37.332075   1.091410    0.514496
# min    277.000000   1.000000    0.000000
# 25%    303.000000   3.000000    0.000000
# 50%    311.000000   3.000000    0.000000
# 75%    371.000000   3.000000    1.000000
# max    382.000000   4.000000    1.000000

# %%
import matplotlib.pyplot as plt

plt.hist(df['Weight'])
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.show()

# %%
df['Label'].value_counts().plot(kind='bar')
plt.title('Apple vs Banana Count')
plt.show()

# %%
df['Colour'].value_counts().plot(kind='bar')
plt.title('Colour Distribution')
plt.show()

# %%
df['Label'].value_counts()
# Out:
# Label
# Banana    9
# Apple     8
# Name: count, dtype: int64

# %%
df[df['Label']=='Apple']['Weight'].mean()
# Out:
# np.float64(371.5)

# %%
df[df['Label']=='Banana']['Weight'].mean()
# Out:
# np.float64(300.77777777777777)

# %%
df[df['Label']=='Apple']['Weight'].mean()
# Out:
# np.float64(371.5)

# %%
df[df['Label'] == 'Banana']['Weight'].mean()
# Out:
# np.float64(300.77777777777777)

# %%
df[df['Label'] == 'Apple']['Weight'].mean()
# Out:
# np.float64(371.5)

# %%
df[df['Label'] == 'Banana']['Weight'].mean()
# Out:
# np.float64(300.77777777777777)

# %%
df['Colour'].value_counts()
# Out:
# Colour
# 3    9
# 1    4
# 4    4
# Name: count, dtype: int64

# %%
df.sort_values(by='Weight', ascending=False).head(1)
# Out:
#    Weight  Colour  Label Fruit_Size  Label_Code
# 6     382       1  Apple      Heavy           1

# %%
df.loc[df['Weight'].idxmax()]
# Out:
# Weight          382
# Colour            1
# Label         Apple
# Fruit_Size    Heavy
# Label_Code        1
# Name: 6, dtype: object

# %%
df.loc[df['Weight'].idxmax()]
# Out:
# Weight          382
# Colour            1
# Label         Apple
# Fruit_Size    Heavy
# Label_Code        1
# Name: 6, dtype: object

# %%
import seaborn as sns

sns.scatterplot(
    x='Weight',
    y='Colour',
    hue='Label',
    data=df
)

plt.show()

# %%
df['Label_Code']=df['Label'].map({
    'Apple':1,
    'Banana':0
})

# %%
import seaborn as sns

sns.heatmap(
    df[['Weight','Colour','Label_Code']].corr(),
    annot=True
)

plt.show()

# %%
df['Weight'].mean()
# Out:
# np.float64(334.05882352941177)

# %%
import matplotlib.pyplot as plt

df['Label'].value_counts().plot(kind='bar')
plt.title('Apple vs Banana Count')
plt.savefig('fruit_count.png')
plt.show()

# %%
plt.hist(df['Weight'])
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.savefig('weight_distribution.png')
plt.show()

# %%
df['Colour'].value_counts().plot(kind='bar')
plt.title('Colour Distribution')
plt.savefig('colour_distribution.png')
plt.show()

# %%
import seaborn as sns

sns.scatterplot(
    x='Weight',
    y='Colour',
    hue='Label',
    data=df
)

plt.title('Weight vs Colour')
plt.savefig('scatter_plot.png')
plt.show()
